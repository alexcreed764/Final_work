# %% [markdown]
# <a href="https://colab.research.google.com/github/alexcreed764/Final_work/blob/main/%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_pynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(5)
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  robot
# 3  human
# 4  robot

# %%
one_hot = pd.DataFrame({'human': [1 if str == 'human' else 0 for str in lst], 'robot': [0 if str == 'human' else 1 for str in lst]})
one_hot.head(5)
# Out:
#    human  robot
# 0      1      0
# 1      0      1
# 2      0      1
# 3      1      0
# 4      0      1
